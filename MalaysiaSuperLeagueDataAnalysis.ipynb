# %%
########################################################
# Author: Izzat Zanail - izzat.zanail@gmail.com
# Language: Python 3.12
# Created: 2024-03-21
# Updated: 2024-11-03
# Project: Malaysia Super League Data Analysis
# Description: MSL Football Clubs Data Analysis from Transfermarkt website
########################################################

# %%
# Import libraries

import requests
import pandas as pd
import numpy as np
import math
import os

# %%
# Read cvs files

path_csv = os.getcwd() + '\\datacsv'

df_msl_teams = pd.read_csv(path_csv + '\\' + 'MSL_TeamPages.csv')
df_msl_player = pd.read_csv(path_csv + '\\' + 'MSL_FullData.csv')

# %%
df_msl_player['TEAM'] = df_msl_player['TEAM_CLEANED']
df_msl_player = df_msl_player.drop(columns='TEAM_CLEANED')
df_msl_player
# Out:
#       SEASON                   TEAM           PLAYER NUMBER  AGE  \
# 0       2016  Johor Darul Ta'zim FC  Farizal Marlias      1   29
# 1       2016  Johor Darul Ta'zim FC    Izham Tarmizi     24   24
# 2       2016  Johor Darul Ta'zim FC     Haziq Nadzli     30   17
# 3       2016  Johor Darul Ta'zim FC     Bruno Soares      2   27
# 4       2016  Johor Darul Ta'zim FC   Marcos António      6   32
# ...      ...                    ...              ...    ...  ...
# 3428    2024                PDRM FC      Imran Samso      -   26
# 3429    2024                PDRM FC    Syakimi Karim     50   23
# 3430    2024     Negeri Sembilan FC     Azeem Farhan     31   22
# 3431    2024              Penang FC     Daniel Irfan     88   23
# 3432    2024              Penang FC     Aidil Danial     55   22
#
#                 POSITION POSITION_TYPE  VALUE_EUR  \
# 0             Goalkeeper    Goalkeeper        0.0
# 1             Goalkeeper    Goalkeeper        1.0
# 2             Goalkeeper    Goalkeeper        2.0
# 3            Centre-Back     Defenders   700000.0
# 4            Centre-Back     Defenders   400000.0
# ...                  ...           ...        ...
# 3428        Right Winger      Forwards     3785.0
# 3429      Centre-Forward      Forwards     3790.0
# 3430          Goalkeeper     Defenders     3794.0
# 3431  Attacking Midfield   Midfielders     3841.0
# 3432         Left Winger   Midfielders     3843.0
#
#                                             PLAYER_LINK NATIONALITY
# 0     https://www.transfermarkt.com/farizal-marlias/...    Malaysia
# 1     https://www.transfermarkt.com/izham-tarmizi/pr...    Malaysia
# 2     https://www.transfermarkt.com/haziq-nadzli/pro...    Malaysia
# 3     https://www.transfermarkt.com/bruno-soares/pro...      Brazil
# 4     https://www.transfermarkt.com/marcos-antonio/p...      Brazil
# ...                                                 ...         ...
# 3428  https://www.transfermarkt.com/imran-samso/prof...    Malaysia
# 3429  https://www.transfermarkt.com/syakimi-karim/pr...    Malaysia
# 3430  https://www.transfermarkt.com/azeem-farhan/pro...    Malaysia
# 3431  https://www.transfermarkt.com/daniel-irfan/pro...    Malaysia
# 3432  https://www.transfermarkt.com/aidil-danial/pro...    Malaysia
#
# [3433 rows x 10 columns]

# %%
df_msl_teams.head(n=10)
# Out:
#    SEASON                   TEAM  SQUAD_SIZE  NO_OF_FOREIGNERS  \
#
.0  https://www.transfermarkt.com/johor-darul-tazi...
# 72         9930000.0  https://www.transfermarkt.com/johor-darul-tazi...
# 86        10830000.0  https://www.transfermarkt.com/johor-darul-tazi...

# %%
max_foreigners = df_msl_teams.loc[df_msl_teams['NO_OF_FOREIGNERS'].idxmax()].iloc[3]
min_foreigners = df_msl_teams.loc[df_msl_teams['NO_OF_FOREIGNERS'].idxmin()].iloc[3]

max_team_size = df_msl_teams.loc[df_msl_teams['SQUAD_SIZE'].idxmax()].iloc[2]
min_team_size = df_msl_teams.loc[df_msl_teams['SQUAD_SIZE'].idxmin()].iloc[2]

highest_value = df_msl_teams.loc[df_msl_teams['MARKET_VALUE_EUR'].idxmax()].iloc[4]
lowest_value = df_msl_teams.loc[df_msl_teams['MARKET_VALUE_EUR'].idxmin()].iloc[4]

# %%
# Team with MOST import players of all time
df_msl_teams[df_msl_teams['NO_OF_FOREIGNERS'] == max_foreigners]
# Out:
#     SEASON                   TEAM  SQUAD_SIZE  NO_OF_FOREIGNERS  \
# 86    2024  Johor Darul Ta'zim FC          35                15
#
#     MARKET_VALUE_EUR                                               LINK
# 86        10830000.0  https://www.transfermarkt.com/johor-darul-tazi...

# %%
# Team with LEAST import players of all time
df_msl_teams[df_msl_teams['NO_OF_FOREIGNERS'] == min_foreigners]
# Out:
#     SEASON                   TEAM  SQUAD_SIZE  NO_OF_FOREIGNERS  \
# 59    2021  Petaling Jaya City FC          29                 0
# 70    2022  Petaling Jaya City FC          28                 0
#
#     MARKET_VALUE_EUR                                               LINK
# 59         1540000.0  https://www.transfermarkt.com/petaling-jaya-ci...
# 70         2360000.0  https://www.transfermarkt.com/petaling-jaya-ci...

# %%
# Team with BIGGEST Squad Size of all time
df_msl_teams[df_msl_teams['SQUAD_SIZE'] == max_team_size]
# Out:
#     SEASON         TEAM  SQUAD_SIZE  NO_OF_FOREIGNERS  MARKET_VALUE_EUR  \
# 84    2023  Kelantan FC          56                10         2500000.0
#
#                                                  LINK
# 84  https://www.transfermarkt.com/kelantan-fa/star...

# %%
# Team with SMALLEST Squad Size of all time
df_msl_teams[df_msl_teams['SQUAD_SIZE'] == min_team_size]
# Out:
#     SEASON           TEAM  SQUAD_SIZE  NO_OF_FOREIGNERS  MARKET_VALUE_EUR  \
# 90    2024  Sri Pahang FC          26                 5         3800000.0
#
#                                                  LINK
# 90  https://www.transfermarkt.com/sri-pahang-fc/st...

# %%
# HIGEST VALUE Team of all time
df_msl_teams[df_msl_teams['MARKET_VALUE_EUR'] == highest_value]
# Out:
#     SEASON                   TEAM  SQUAD_SIZE  NO_OF_FOREIGNERS  \
# 12    2018  Johor Darul Ta'zim FC          38                13
#
#     MARKET_VALUE_EUR                                               LINK
# 12        11780000.0  https://www.transfermarkt.com/johor-darul-tazi...

# %%
# LOWEST VALUE Team of all time
df_msl_teams[df_msl_teams['MARKET_VALUE_EUR'] == lowest_value]
# Out:
#     SEASON      TEAM  SQUAD_SIZE  NO_OF_FOREIGNERS  MARKET_VALUE_EUR  \
# 47    2020  Sabah FC          29                 6          450000.0
#
#                                                  LINK
# 47  https://www.transfermarkt.com/sabah-fc/startse...

# %%
# Average Team Value Per Season - Teams currently competing in season 24/25

team_2024 = ["Johor Darul Ta'zim FC" ,'Selangor FC', 'Terengganu FC', 'Kedah Darul Aman FC' ,'Sri Pahang FC' ,'Kelantan Darul Naim FC' ,'Kuala Lumpur City FC' ,'Kuching City FC' ,'Negeri Sembilan FC' ,'PDRM FC' ,'Penang FC' ,'Perak FC' ,'Sabah FC' ]

avg_team_value = df_msl_teams.pivot_table(values='MARKET_VALUE_EUR', index='TEAM', aggfunc='mean').reset_index()
avg_team_value = avg_team_value.fillna(value=0).sort_values(by='MARKET_VALUE_EUR', ascending=False)

pd.options.display.float_format = '{:,.0f}'.format

avg_team_value[avg_team_value['TEAM'].isin(team_2024)]
# Out:
#                       TEAM  MARKET_VALUE_EUR
# 1    Johor Darul Ta'zim FC         8,576,250
# 17             Selangor FC         3,901,250
# 2      Kedah Darul Aman FC         3,771,250
# 19           Sri Pahang FC         3,260,000
# 6          Kuching City FC         3,195,000
# 20           Terengganu FC         3,140,000
# 14                Sabah FC         3,084,000
# 5     Kuala Lumpur City FC         3,071,667
# 11                Perak FC         2,870,000
# 8       Negeri Sembilan FC         2,782,500
# 10               Penang FC         2,708,000
# 3   Kelantan Darul Naim FC         2,615,000
# 9                  PDRM FC         1,936,667

# %%
# Team market value every season - Teams currently competing in season 24/25

avg_team_value_per_season = df_msl_teams.pivot_table(values='MARKET_VALUE_EUR', index='TEAM', columns='SEASON', aggfunc='mean').reset_index()
avg_team_value_per_season = avg_team_value_per_season.fillna(value=0)

#avg_team_value_per_season

avg_team_value_per_season = avg_team_value_per_season[avg_team_value_per_season['TEAM'].isin(team_2024)]

avg_team_value_per_season = avg_team_value_per_season.merge(avg_team_value, how='left', on='TEAM')
avg_team_value_per_season.rename(columns={'MARKET_VALUE_EUR': 'AVG_MARKET_VALUE_EUR'}, inplace = True)

avg_team_value_per_season.sort_values(by='AVG_MARKET_VALUE_EUR', ascending=False)
# Out:
#                       TEAM      2017       2018      2019      2020      2021  \
# 0    Johor Darul Ta'zim FC 6,630,000 11,780,000 7,400,000 6,780,000 6,680,000
# 10             Selangor FC 2,980,000  1,900,000 2,130,000 3,930,000 3,450,000
# 1      Kedah Darul Aman FC 3,030,000  3,780,000 3,130,000 3,950,000 3,260,000
# 11           Sri Pahang FC 2,850,000  2,250,000 3,180,000 2,850,000 2,710,000
# 4          Kuching City FC         0          0         0         0         0
# 12           Terengganu FC         0  1,180,000 2,200,000 3,180,000 2,800,000
# 9                 Sabah FC         0          0         0   450,000 2,890,000
# 3     Kuala Lumpur City FC         0  1,780,000 1,700,000         0 3,460,000
# 8                 Perak FC 1,850,000  2,450,000 2,400,000 3,200,000 3,930,000
# 5       Negeri Sembilan FC         0  1,700,000         0         0         0
# 7                Penang FC 2,250,000          0         0         0 2,400,000
# 2   Kelantan Darul Naim FC         0          0         0         0         0
# 6                  PDRM FC         0          0         0   850,000         0
#
#         2022      2023       2024  AVG_MARKET_VALUE_EUR
# 0  8,580,000 9,930,000 10,830,000             8,576,250
# 10 3,910,000 5,930,000  6,980,000             3,901,250
# 1  3,870,000 5,400,000  3,750,000             3,771,250
# 11 4,200,000 4,240,000  3,800,000             3,260,000
# 4          0 3,470,000  2,920,000             3,195,000
# 12 3,360,000 4,560,000  4,700,000             3,140,000
# 9  3,550,000 4,640,000  3,890,000             3,084,000
# 3  3,500,000 4,610,000  3,380,000             3,071,667
# 8          0 3,230,000  3,030,000             2,870,000
# 5  3,160,000 3,790,000  2,480,000             2,782,500
# 7  3,010,000 3,430,000  2,450,000             2,708,000
# 2          0 2,620,000  2,610,000             2,615,000
# 6          0 2,410,000  2,550,000             1,936,667

# %%
# No of import players Per Team, Per Season - Teams currently competing in season 24/25
no_import_players = df_msl_teams.pivot_table(values='NO_OF_FOREIGNERS', index='TEAM', columns='SEASON').reset_index()
no_import_players = no_import_players.fillna(value=0)

no_import_players = no_import_players[no_import_players['TEAM'].isin(team_2024)]

no_import_players
# Out:
# SEASON                    TEAM  2017  2018  2019  2020  2021  2022  2023  2024
# 1        Johor Darul Ta'zim FC     9    13     6     7     8    10    10    15
# 2          Kedah Darul Aman FC     3     8     9     6     5     7     9     5
# 3       Kelantan Darul Naim FC     0     0     0     0     0     0    10    10
# 5         Kuala Lumpur City FC     0     5     5     0     4     4     8     5
# 6              Kuching City FC     0     0     0     0     0     0    14    10
# 8           Negeri Sembilan FC     0     8     0     0     0     7     7     8
# 9                      PDRM FC     0     0     0     6     0     0     9     9
# 10                   Penang FC     8     0     0     0     5     5    10     5
# 11                    Perak FC     6     6     7     5     9     0     8     8
# 14                    Sabah FC     0     0     0     6     6     6     9     8
# 17                 Selangor FC     8     5     7     6     8     9    10    11
# 19               Sri Pahang FC     5     8     6     5     8     8    10     5
# 20               Terengganu FC     0     7     6     7     8     8    10     8

# %%
df_msl_player.loc[df_msl_player['AGE'].idxmax()]
# Out:
# SEASON                                                        2022
# TEAM                                               Kuching City FC
# PLAYER                                                      Ramesh
# NUMBER                                                          12
# AGE                                                             41
# POSITION                                                 Left-Back
# POSITION_TYPE                                            Defenders
# VALUE_EUR                                                    2,748
# PLAYER_LINK      https://www.transfermarkt.com/ramesh/profil/sp...
# NATIONALITY                                               Malaysia
# Name: 2732, dtype: object

# %%
max_age = df_msl_player.loc[df_msl_player['AGE'].idxmax()].iloc[4]
min_age = df_msl_player.loc[df_msl_player['AGE'].idxmin()].iloc[4]

max_value = df_msl_player.loc[df_msl_player['VALUE_EUR'].idxmax()].iloc[7]

non_zero_value = df_msl_player[df_msl_player['VALUE_EUR'] > 0]
min_value = non_zero_value.loc[non_zero_value['VALUE_EUR'].idxmin()].iloc[7]

print('Oldest age in MSL history: ' + str(max_age) + ' years old')
print('Youngest age in MSL history: ' + str(min_age) + ' years old')
print('Highest value in MSL history: EUR ' + str(max_value))
print('Lowest value in MSL history: EUR ' + str(min_value))
# Out:
# Oldest age in MSL history: 41 years old
# Youngest age in MSL history: 15 years old
# Highest value in MSL history: EUR 3000000.0
# Lowest value in MSL history: EUR 1.0

# %%
# Top 30 players with highest value in MSL history since 2016

df_msl_player.sort_values(by='VALUE_EUR', ascending=False).head(n=30)
# 2928    2022            Kelantan FC       Haikal Pauzi      -   15
# 2946    2022            Kelantan FC      Izaham Haslin     97   15
#
#             POSITION POSITION_TYPE  VALUE_EUR  \
# 32    Centre-Forward      Forwards         32
# 543      Centre-Back   Midfielders        545
# 2894      Goalkeeper     Defenders      2,910
# 2909     Centre-Back   Midfielders      2,925
# 2928     Left Winger    Goalkeeper      2,944
# 2946  Centre-Forward     Defenders      2,962
#
#                                             PLAYER_LINK NATIONALITY
# 32    https://www.transfermarkt.com/hadi-fayyadh/pro...    Malaysia
# 543   https://www.transfermarkt.com/nik-umar-nik-azi...    Malaysia
# 2894  https://www.transfermarkt.com/mohd-afif/profil...    Malaysia
# 2909  https://www.transfermarkt.com/farish-ainun/pro...    Malaysia
# 2928  https://www.transfermarkt.com/haikal-pauzi/pro...    Malaysia
# 2946  https://www.transfermarkt.com/izaham-haslin/pr...    Malaysia

# %%
# YOUNGEST Player in 2024
season_2024 = df_msl_player[df_msl_player['SEASON'] == 2024]
season_2024

youngest_2024 = season_2024.loc[season_2024['AGE'].idxmin()].iloc[4]

season_2024[season_2024['AGE'] == youngest_2024]
# Out:
#       SEASON                   TEAM          PLAYER NUMBER  AGE    POSITION  \
# 2987    2024  Johor Darul Ta'zim FC  Christian Abad     12   18  Goalkeeper
# 3397    2024  Johor Darul Ta'zim FC  Christian Abad     12   18  Goalkeeper
#
#      POSITION_TYPE  VALUE_EUR  \
# 2987     Defenders      3,003
# 3397     Defenders      3,429
#
#                                             PLAYER_LINK NATIONALITY
# 2987  https://www.transfermarkt.com/christian-abad/p...    Malaysia
# 3397  https://www.transfermarkt.com/christian-abad/p...    Malaysia

# %%
# OLDEST Player of all time
df_msl_player[df_msl_player['AGE'] == max_age]
# Out:
#       SEASON             TEAM  PLAYER NUMBER  AGE   POSITION POSITION_TYPE  \
# 2732    2022  Kuching City FC  Ramesh     12   41  Left-Back     Defenders
#
#       VALUE_EUR                                        PLAYER_LINK NATIONALITY
# 2732      2,748  https://www.transfermarkt.com/ramesh/profil/sp...    Malaysia

# %%
# OLDEST Player in 2024
oldest_2024 = season_2024.loc[season_2024['AGE'].idxmax()].iloc[4]

season_2024[season_2024['AGE'] == oldest_2024]
# Out:
#       SEASON                   TEAM           PLAYER NUMBER  AGE  \
# 2985    2024  Johor Darul Ta'zim FC  Farizal Marlias      1   38
# 3004    2024  Johor Darul Ta'zim FC       Natxo Insa     30   38
# 3230    2024        Kuching City FC       Wan Azraie     38   38
#
#               POSITION POSITION_TYPE  VALUE_EUR  \
# 2985        Goalkeeper    Goalkeeper    100,000
# 3004  Central Midfield   Midfielders     75,000
# 3230        Goalkeeper    Goalkeeper     50,000
#
#                                             PLAYER_LINK NATIONALITY
# 2985  https://www.transfermarkt.com/farizal-marlias/...    Malaysia
# 3004  https://www.transfermarkt.com/natxo-insa/profi...    Malaysia
# 3230  https://www.transfermarkt.com/wan-azraie/profi...    Malaysia

# %%
# Average player's age per team in every season

pivot_msl = df_msl_player.pivot_table(values='AGE', index='SEASON', columns='TEAM', aggfunc='mean').fillna(value=0).round(2)

pivot_msl_2024 = pivot_msl.filter(items=team_2024)
pivot_msl_2024
# Out:
#         Johor Darul Ta'zim FC  Selangor FC  Terengganu FC  \
# SEASON
# 2016                       25           24              0
# 2017                       26           24             26
# 2018                       25           25             26
# 2019                       25           24             25
# 2020                       26           23             24
# 2021                       27           23             24
# 2022                       27           23             24
# 2024                       29           25             26
#
#         Kedah Darul Aman FC  Sri Pahang FC  Kelantan Darul Naim FC  \
# SEASON
# 2016                     22             24                       0
# 2017                     24             25                       0
# 2018                     24             26                       0
# 2019                     24             25                       0
# 2020                     25             25                       0
# 2021                     25             25                       0
# 2022                     25             27                      26
# 2024                     26             28                      26
#
#         Kuala Lumpur City FC  Kuching City FC  Negeri Sembilan FC  PDRM FC  \
# SEASON
# 2016                       0                0                   0        0
# 2017                      25                0                  25        0
# 2018                      26                0                   0        0
# 2019                       0                0                   0       26
# 2020                      26                0                   0        0
# 2021                      24                0                  26        0
# 2022                      25               27                  26       26
# 2024                      28               28                  26       27
#
#         Penang FC  Perak FC  Sabah FC
# SEASON
# 2016           24        24         0
# 2017            0        25         0
# 2018            0        25         0
# 2019            0        24        26
# 2020           24        24        25
# 2021           25         0        26
# 2022           24        22        27
# 2024           26        26        28

# %%
# Average player's value per team in every season

pivot_msl = df_msl_player.pivot_table(values='VALUE_EUR', index='SEASON', columns='TEAM', aggfunc='mean').fillna(value=0).round(0)

pivot_msl_2024 = pivot_msl.filter(items=team_2024).reset_index()
pivot_msl_2024
# Out:
#    SEASON  Johor Darul Ta'zim FC  Selangor FC  Terengganu FC  \
# 0    2016                170,846       40,122              0
# 1    2017                244,366       14,733         16,896
# 2    2018                240,029       52,966         59,160
# 3    2019                213,113       64,152         74,990
# 4    2020                233,566      110,657         72,265
# 5    2021                247,693       79,753         63,367
# 6    2022                293,445      156,140        110,112
# 7    2024                300,873      184,240        147,287
#
#    Kedah Darul Aman FC  Sri Pahang FC  Kelantan Darul Naim FC  \
# 0               58,424         38,020                       0
# 1               56,318         46,941                       0
# 2               62,212        118,589                       0
# 3               68,532         72,924                       0
# 4              103,758         98,193                       0
# 5               63,796        184,419                       0
# 6              132,428        122,356                  63,382
# 7              105,295        146,154                  57,964
#
#    Kuala Lumpur City FC  Kuching City FC  Negeri Sembilan FC  PDRM FC  \
# 0                     0                0                   0        0
# 1                30,341                0              35,396        0
# 2                50,032                0                   0        0
# 3                     0                0                   0   23,519
# 4               103,562                0                   0        0
# 5                98,251                0             100,096        0
# 6               110,377           39,823              83,167   25,737
# 7               112,894           73,524              80,231   64,693
#
#    Penang FC  Perak FC  Sabah FC
# 0     34,448    12,873         0
# 1          0    30,850         0
# 2          0    78,985         0
# 3          0    56,671    17,683
# 4     42,613   101,936    62,176
# 5     51,007         0    80,278
# 6     70,810    37,263   119,283
# 7     76,860   108,282   111,190
